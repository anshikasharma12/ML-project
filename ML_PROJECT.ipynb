# %% [markdown]
# ##Weather prediction

# %%
import pandas as pd

# %%
url='https://raw.githubusercontent.com/anshikasharma12/ML-project/main/seattle-weather.csv'
df=pd.read_csv(url)
df
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1     2012-01-02           10.9      10.6       2.8   4.5     rain
# 2     2012-01-03            0.8      11.7       7.2   2.3     rain
# 3     2012-01-04           20.3      12.2       5.6   4.7     rain
# 4     2012-01-05            1.3       8.9       2.8   6.1     rain
# ...          ...            ...       ...       ...   ...      ...
# 1456  2015-12-27            8.6       4.4       1.7   2.9     rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3     rain
# 1458  2015-12-29            0.0       7.2       0.6   2.6      fog
# 1459  2015-12-30            0.0       5.6      -1.0   3.4      sun
# 1460  2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 6 columns]

# %%
df.head()
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1  2012-01-02           10.9      10.6       2.8   4.5     rain
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain
# 3  2012-01-04           20.3      12.2       5.6   4.7     rain
# 4  2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1461 non-null   object
#  1   precipitation  1461 non-null   float64
#  2   temp_max       1461 non-null   float64
#  3   temp_min       1461 non-null   float64
#  4   wind           1461 non-null   float64
#  5   weather        1461 non-null   object
# dtypes: float64(4), object(2)
# memory usage: 68.6+ KB

# %% [markdown]
# ##How to Analyze DataFrames?

# %%
##.shape---it shows the total no. of rows and no. of columns of the data frame
df.shape
# Out:
# (1461, 6)

# %%
## .index---this provides the index of the dataframe
df.index
# Out:
# RangeIndex(start=0, stop=1461, step=1)

# %%
## .columns-----shows name of each column
df.columns
# Out:
# Index(['date', 'precipitation', 'temp_max', 'temp_min', 'wind', 'weather'], dtype='object')

# %%
## .dtypes----shows the datatype of each column
df.dtypes
# Out:
# date              object
# precipitation    float64
# temp_max         float64
# temp_min         float64
# wind             float64
# weather           object
# dtype: object

# %%
#.unique()-----it shows the unique value in a column.
#it can be applied on a single column only,not on the whole dataframe
df['weather'].unique()
# Out:
# array(['drizzle', 'rain', 'sun', 'snow', 'fog'], dtype=object)

# %%
# .nunique()-----it shows the total no. of unique values in each columns
#it can be applied on a single column as well as on whole dataframe
df.nunique()
# Out:
# date             1461
# precipitation     111
# temp_max           67
# temp_min           55
# wind               79
# weather             5
# dtype: int64

# %%
# .count-----shows the total no. of non null in each columns.
#it can be applied on a single column as well as whole dataframe
df.count()
# Out:
# date             1461
# precipitation    1461
# temp_max         1461
# temp_min         1461
# wind             1461
# weather          1461
# dtype: int64

# %%
# .value_counts-----shows all the unique values with their count in a column
# applied on single column only
df['weather'].value_counts()
# Out:
# rain       641
# sun        640
# fog        101
# drizzle     53
# snow        26
# Name: weather, dtype: int64

# %%
# .info-------provides basic information about the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1461 non-null   object
#  1   precipitation  1461 non-null   float64
#  2   temp_max       1461 non-null   float64
#  3   temp_min       1461 non-null   float64
#  4   wind           1461 non-null   float64
#  5   weather        1461 non-null   object
# dtypes: float64(4), object(2)
# memory usage: 68.6+ KB

# %%
df.describe()
# Out:
#        precipitation     temp_max     temp_min         wind
# count    1461.000000  1461.000000  1461.000000  1461.000000
# mean        3.029432    16.439083     8.234771     3.241136
# std         6.680194     7.349758     5.023004     1.437825
# min         0.000000    -1.600000    -7.100000     0.400000
# 25%         0.000000    10.600000     4.400000     2.200000
# 50%         0.000000    15.600000     8.300000     3.000000
# 75%         2.800000    22.200000    12.200000     4.000000
# max        55.900000    35.600000    18.300000     9.500000

# %% [markdown]
# ##QUERIES

# %%
# 1. find all the unique "wind" values in the data
df['wind'].unique()
# Out:
# array([4.7, 4.5, 2.3, 6.1, 2.2, 2. , 3.4, 5.1, 1.9, 1.3, 5.3, 3.2, 5. ,
#        5.6, 1.6, 8.2, 4.8, 3.6, 5.4, 1.4, 3.9, 2.7, 2.6, 4.3, 2.9, 2.4,
#        3. , 3.1, 1.8, 2.1, 8.1, 7.5, 5.9, 3.5, 6.4, 4.2, 7. , 6.2, 2.5,
#        2.8, 5.8, 3.8, 5.2, 4.4, 6.8, 4.1, 4. , 8. , 4.6, 1.5, 6.3, 3.3,
#        3.7, 1.7, 6. , 1.1, 7.3, 6.5, 5.7, 5.5, 4.9, 1. , 1.2, 9.5, 0.6,
#        7.1, 7.6, 0.9, 0.4, 7.9, 7.2, 0.5, 0.7, 8.8, 0.8, 6.6, 6.9, 6.7,
#        7.7])

# %%
# 2. find the number of times when the weather is exactly'rain'
df[df.weather=='rain']
# Out:
#             date  precipitation  temp_max  temp_min  wind weather
# 1     2012-01-02           10.9      10.6       2.8   4.5    rain
# 2     2012-01-03            0.8      11.7       7.2   2.3    rain
# 3     2012-01-04           20.3      12.2       5.6   4.7    rain
# 4     2012-01-05            1.3       8.9       2.8   6.1    rain
# 5     2012-01-06            2.5       4.4       2.2   2.2    rain
# ...          ...            ...       ...       ...   ...     ...
# 1452  2015-12-23            6.1       5.0       2.8   7.6    rain
# 1453  2015-12-24            2.5       5.6       2.2   4.3    rain
# 1454  2015-12-25            5.8       5.0       2.2   1.5    rain
# 1456  2015-12-27            8.6       4.4       1.7   2.9    rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3    rain
#
# [641 rows x 6 columns]

# %%
df.groupby('weather').get_group('rain')
# Out:
#             date  precipitation  temp_max  temp_min  wind weather
# 1     2012-01-02           10.9      10.6       2.8   4.5    rain
# 2     2012-01-03            0.8      11.7       7.2   2.3    rain
# 3     2012-01-04           20.3      12.2       5.6   4.7    rain
# 4     2012-01-05            1.3       8.9       2.8   6.1    rain
# 5     2012-01-06            2.5       4.4       2.2   2.2    rain
# ...          ...            ...       ...       ...   ...     ...
# 1452  2015-12-23            6.1       5.0       2.8   7.6    rain
# 1453  2015-12-24            2.5       5.6       2.2   4.3    rain
# 1454  2015-12-25            5.8       5.0       2.2   1.5    rain
# 1456  2015-12-27            8.6       4.4       1.7   2.9    rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3    rain
#
# [641 rows x 6 columns]

# %%
# 3. find the number of times when the 'wind speed was exactly 4km/h'
df[df.wind==4]
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 103   2012-04-13            0.0      15.0       3.9   4.0  drizzle
# 141   2012-05-21           14.0      16.7      10.0   4.0     rain
# 201   2012-07-20           15.2      19.4      13.9   4.0     rain
# 309   2012-11-05            0.8      15.0       7.8   4.0     rain
# 396   2013-01-31            3.0       9.4       7.2   4.0     rain
# 473   2013-04-18            5.3      11.7       6.7   4.0     rain
# 487   2013-05-02            0.0      20.6       6.7   4.0      sun
# 514   2013-05-29            5.6      16.1       9.4   4.0     rain
# 721   2013-12-22           10.7      10.6       8.3   4.0     rain
# 835   2014-04-15            0.5      14.4       7.8   4.0     rain
# 873   2014-05-23            3.8      20.0      12.8   4.0     rain
# 893   2014-06-12            1.8      21.7      12.2   4.0     rain
# 1080  2014-12-16            0.0      10.0       8.3   4.0      sun
# ...

# %%
df.groupby('wind').get_group(4)
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 103   2012-04-13            0.0      15.0       3.9   4.0  drizzle
# 141   2012-05-21           14.0      16.7      10.0   4.0     rain
# 201   2012-07-20           15.2      19.4      13.9   4.0     rain
# 309   2012-11-05            0.8      15.0       7.8   4.0     rain
# 396   2013-01-31            3.0       9.4       7.2   4.0     rain
# 473   2013-04-18            5.3      11.7       6.7   4.0     rain
# 487   2013-05-02            0.0      20.6       6.7   4.0      sun
# 514   2013-05-29            5.6      16.1       9.4   4.0     rain
# 721   2013-12-22           10.7      10.6       8.3   4.0     rain
# 835   2014-04-15            0.5      14.4       7.8   4.0     rain
# 873   2014-05-23            3.8      20.0      12.8   4.0     rain
# 893   2014-06-12            1.8      21.7      12.2   4.0     rain
# 1080  2014-12-16            0.0      10.0       8.3   4.0      sun
# ...

# %%
# 4. find out all the null values in the data
df.isnull().sum()
# Out:
# date             0
# precipitation    0
# temp_max         0
# temp_min         0
# wind             0
# weather          0
# dtype: int64

# %%
# 5. rename the column name 'wind' to 'wind speed'
#inplace= True------for permannent rename
df.rename(columns={'wind':'wind speed'})
# Out:
#             date  precipitation  temp_max  temp_min  wind speed  weather
# 0     2012-01-01            0.0      12.8       5.0         4.7  drizzle
# 1     2012-01-02           10.9      10.6       2.8         4.5     rain
# 2     2012-01-03            0.8      11.7       7.2         2.3     rain
# 3     2012-01-04           20.3      12.2       5.6         4.7     rain
# 4     2012-01-05            1.3       8.9       2.8         6.1     rain
# ...          ...            ...       ...       ...         ...      ...
# 1456  2015-12-27            8.6       4.4       1.7         2.9     rain
# 1457  2015-12-28            1.5       5.0       1.7         1.3     rain
# 1458  2015-12-29            0.0       7.2       0.6         2.6      fog
# 1459  2015-12-30            0.0       5.6      -1.0         3.4      sun
# 1460  2015-12-31            0.0       5.6      -2.1         3.5      sun
#
# [1461 rows x 6 columns]

# %%
# 6. mean of 'precipitaion'
df.precipitation.mean()
# Out:
# 3.02943189596167

# %%
# 7. standard deviation of 'temp_max'
df.temp_max.std()
# Out:
# 7.349758097360177

# %%
# 8. variance of 'temp_min'
df['temp_min'].var()
# Out:
# 25.230570991908344

# %%
# 9. find all the instances when 'rain' was recorded
#str container----df[df['weather'].str.contains('rain')]
df[df.weather=='rain']
# Out:
#             date  precipitation  temp_max  temp_min  wind weather
# 1     2012-01-02           10.9      10.6       2.8   4.5    rain
# 2     2012-01-03            0.8      11.7       7.2   2.3    rain
# 3     2012-01-04           20.3      12.2       5.6   4.7    rain
# 4     2012-01-05            1.3       8.9       2.8   6.1    rain
# 5     2012-01-06            2.5       4.4       2.2   2.2    rain
# ...          ...            ...       ...       ...   ...     ...
# 1452  2015-12-23            6.1       5.0       2.8   7.6    rain
# 1453  2015-12-24            2.5       5.6       2.2   4.3    rain
# 1454  2015-12-25            5.8       5.0       2.2   1.5    rain
# 1456  2015-12-27            8.6       4.4       1.7   2.9    rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3    rain
#
# [641 rows x 6 columns]

# %%
# 10. find all the instances when 'temp_max is above 6' and 'temp_min is 5'
df[(df['temp_max']>25) & (df['temp_min']==10)]
# Out:
#            date  precipitation  temp_max  temp_min  wind weather
# 531  2013-06-15            0.0      25.6      10.0   2.9     sun
# 627  2013-09-19            0.0      25.6      10.0   1.5     sun
# 986  2014-09-13            0.0      28.3      10.0   4.2     sun

# %%
# 11. mean value of each column aginst each 'weather condition'
df.groupby('weather').mean()
# Out:
# <ipython-input-37-0462e5130231>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('weather').mean()
#          precipitation   temp_max  temp_min      wind
# weather
# drizzle       0.000000  15.926415  7.111321  2.367925
# fog           0.000000  16.757426  7.979208  2.481188
# rain          6.557878  13.454602  7.588768  3.669891
# snow          8.553846   5.573077  0.146154  4.411538
# sun           0.000000  19.861875  9.343750  2.956406

# %%
# 12.max and min value of each coumn against 'weather condition'
df.groupby('weather').min()
# Out:
#                date  precipitation  temp_max  temp_min  wind
# weather
# drizzle  2012-01-01            0.0       1.1      -3.9   0.6
# fog      2012-07-11            0.0       1.7      -3.2   0.8
# rain     2012-01-02            0.0       3.9      -3.8   0.5
# snow     2012-01-14            0.3      -1.1      -4.3   1.6
# sun      2012-01-08            0.0      -1.6      -7.1   0.4

# %%
df.groupby('weather').max()
# Out:
#                date  precipitation  temp_max  temp_min  wind
# weather
# drizzle  2015-10-06            0.0      31.7      16.1   4.7
# fog      2015-12-29            0.0      30.6      17.8   6.6
# rain     2015-12-28           55.9      35.6      18.3   9.5
# snow     2014-11-29           23.9      11.1       5.6   7.0
# sun      2015-12-31            0.0      35.0      18.3   7.7

# %%
# 13. find all instances wher weather is 'fog' and precipitaion is above '50'
df[(df['weather']=='snow') & (df['precipitation']> 20)]
# Out:
#            date  precipitation  temp_max  temp_min  wind weather
# 74   2012-03-15           23.9      11.1       5.6   5.8    snow
# 350  2012-12-16           22.6       6.7       3.3   5.5    snow

# %%
#  14. weather is 'sun' and temp_min is greater than '15' Or temp_max is above 30
df[(df['weather']=='sun') & (df['temp_min']> 15) |(df['temp_max']>30)]
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 216   2012-08-04            0.0      33.9      16.7   3.7      sun
# 217   2012-08-05            0.0      33.9      17.8   1.9      sun
# 224   2012-08-12            0.0      30.6      15.0   3.0      sun
# 225   2012-08-13            0.0      30.6      15.0   2.8      sun
# 227   2012-08-15            0.0      31.1      16.7   4.7      sun
# ...          ...            ...       ...       ...   ...      ...
# 1317  2015-08-10            0.0      28.9      16.1   2.4      sun
# 1318  2015-08-11            0.0      30.0      16.7   4.4      sun
# 1320  2015-08-13            0.0      28.3      15.6   2.2      sun
# 1326  2015-08-19            0.0      31.7      16.1   2.1  drizzle
# 1338  2015-08-31            0.0      18.9      16.1   5.8      sun
#
# [91 rows x 6 columns]

# %%
df.head()
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1  2012-01-02           10.9      10.6       2.8   4.5     rain
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain
# 3  2012-01-04           20.3      12.2       5.6   4.7     rain
# 4  2012-01-05            1.3       8.9       2.8   6.1     rain

# %% [markdown]
# ##Cleaning and Visulize data

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
df.hist(bins=50,figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'precipitation'}>,
#         <Axes: title={'center': 'temp_max'}>],
#        [<Axes: title={'center': 'temp_min'}>,
#         <Axes: title={'center': 'wind'}>]], dtype=object)

# %%
countrain=len(df[df.weather=='rain'])
countsun=len(df[df.weather=='sun'])
countdrizzle=len(df[df.weather=='drizzle'])
countsnow=len(df[df.weather=='snow'])
countfog=len(df[df.weather=='fog'])
print('percent of rain:{:2f}%'.format((countrain/(len(df.weather))*100)))
print('percent of sun:{:2f}%'.format((countsun/(len(df.weather))*100)))
print('percent of drizzle:{:2f}%'.format((countdrizzle/(len(df.weather))*100)))
print('percent of snow:{:2f}%'.format((countsnow/(len(df.weather))*100)))
print('percent of fog:{:2f}%'.format((countfog/(len(df.weather))*100)))
# Out:
# percent of rain:43.874059%
# percent of sun:43.805613%
# percent of drizzle:3.627652%
# percent of snow:1.779603%
# percent of fog:6.913073%

# %%
df=df.drop(['date'],axis=1)

# %%
df.weather.replace(['rain','sun','drizzle','snow','fog'],[0,1,2,3,4],inplace=True)

# %%
df.head()
# Out:
#    precipitation  temp_max  temp_min  wind  weather
# 0            0.0      12.8       5.0   4.7        2
# 1           10.9      10.6       2.8   4.5        0
# 2            0.8      11.7       7.2   2.3        0
# 3           20.3      12.2       5.6   4.7        0
# 4            1.3       8.9       2.8   6.1        0

# %%
df.to_csv("prediction_data.csv")

# %% [markdown]
# ## Missing Attributes

# %%
# To take care of missing attributes, we have three options:
#   1. Get rid of the missing data points
#a=df.dropna(subset="column name")
#a.shape

#    2. Get rid of the whole attribute
# df.drop("col_name",axis=1)

#    3.Set the value to some value(0,mean or median)
# median= df["col_name"].median()
# df["col_name"].fillna(median)

# %% [markdown]
# ## Machine Learning

# %%
x=df.drop(['weather'],axis='columns')
y=df["weather"]
print(x.shape,y.shape)
# Out:
# (1461, 4) (1461,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
#model= LinearRegression()
model=DecisionTreeRegressor()
model.fit(x,y)
# Out:
# DecisionTreeRegressor()

# %%
input=[[20.3,12.2,5.6,4.7]]
ot=model.predict(input)
print('the weather is:')
if(ot==0):
  print('rain')
elif (ot==1):
  print('sun')
elif (ot==2):
  print('drizzle')
elif (ot==3):
  print('snow')
else:
  print('fog')
# Out:
# the weather is:
# rain
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
